# %%
import pandas as pd
import requests

# %%
orig_url='https://drive.google.com/file/d/1onLdet1uLGcyZBC-a4K6V3P1ggeYIOoj/view?usp=sharing'
file_id = orig_url.split('/')[-2]
dwn_url='https://drive.google.com/uc?export=download&id=' + file_id
url = requests.get(dwn_url).url
df3 = pd.read_excel(url)

# %%
import pandas as pd
import requests
from io import StringIO

orig_url='https://drive.google.com/file/d/1gBEqujhcMtXVg2ttp0O4P1-vednR7Lbo/view?usp=sharing'

file_id = orig_url.split('/')[-2]
dwn_url='https://drive.google.com/uc?export=download&id=' + file_id
url = requests.get(dwn_url).text
csv_raw = StringIO(url)
df = pd.read_csv(csv_raw)

# %%
import pandas as pd
import requests
orig_url='https://drive.google.com/file/d/1onLdet1uLGcyZBC-a4K6V3P1ggeYIOoj/view?usp=sharing'
file_id = orig_url.split('/')[-2]
dwn_url='https://drive.google.com/uc?export=download&id=' + file_id
url = requests.get(dwn_url).url
df2 = pd.read_excel(url)

# %%
df3.describe()
# Out:
#         Unnamed: 0         Line      Column      EndLine   EndColumn  \
# count   600.000000   600.000000  600.000000   600.000000  600.000000
# mean    800.500000   637.948333   13.553333   681.940000    5.655000
# std     173.349358   911.991328   26.102415   913.602941    2.559993
# min     501.000000     3.000000    1.000000    18.000000    2.000000
# 25%     650.750000    45.000000    4.250000    93.000000    3.750000
# 50%     800.500000   190.000000    5.000000   241.000000    6.000000
# 75%     950.250000   876.000000    5.000000   930.750000    6.000000
# max    1100.000000  3850.000000  139.000000  3937.000000   14.000000
#
#                CC         CCL         CCO          CI         CLC  ...  \
# count  600.000000  600.000000  600.000000  600.000000  600.000000  ...
# mean     0.097054    0.275000    0.883333    0.356667    0.091401  ...
# std      0.268847    0.872148    5.147220    1.536247    0.258333  ...
# ...

# %%
df3
# Out:
#      Unnamed: 0      ID                                  Name  \
# 0           501  L12334     ClientService$QueueEntriesHandler
# 1           502  L12364  ClientService$RemotelyProcessHandler
# 2           503  L12369          ClientService$DestroyHandler
# 3           504  L12386            ClientService$NewIdHandler
# 4           505  L12159      ClientService$MapPutMultiHandler
# ..          ...     ...                                   ...
# 595        1096  L11021                BlockingQueueManager$2
# 596        1097  L11031                BlockingQueueManager$3
# 597        1098  L11041                BlockingQueueManager$4
# 598        1099  L11051                BlockingQueueManager$5
# 599        1100  L11061                BlockingQueueManager$6
#
#                                               LongName  Parent Component  \
# 0    com.hazelcast.impl.ClientService$QueueEntriesH...  L11986      L103
# ...

# %%
dff = df3.drop('Unnamed: 0' , axis=1)

# %%
df
# Out:
#      Unnamed: 0      ID                                               Name  \
# 0             0    L200                  AsyncClientCall<V extends Object>
# 1             1    L290                            AtomicNumberClientProxy
# 2             2    L381                            AuthenticationException
# 3             3    L214                                               Call
# 4             4    L467  ClientMapEntry<K extends Object, V extends Obj...
# ..          ...     ...                                                ...
# 496         496  L12314                   ClientService$QueueRemoveHandler
# 497         497  L12319                     ClientService$QueuePeekHandler
# 498         498  L12324                     ClientService$QueueSizeHandler
# 499         499  L12299                  ClientService$TopicPublishHandler
# 500         500  L12329        ClientService$QueueRemainingCapacityHandler
#
# ...

# %%
frame = [df,df3]

# %%
data= pd.concat(frame)

# %%
data
# Out:
#      Unnamed: 0      ID                                               Name  \
# 0             0    L200                  AsyncClientCall<V extends Object>
# 1             1    L290                            AtomicNumberClientProxy
# 2             2    L381                            AuthenticationException
# 3             3    L214                                               Call
# 4             4    L467  ClientMapEntry<K extends Object, V extends Obj...
# ..          ...     ...                                                ...
# 595        1096  L11021                             BlockingQueueManager$2
# 596        1097  L11031                             BlockingQueueManager$3
# 597        1098  L11041                             BlockingQueueManager$4
# 598        1099  L11051                             BlockingQueueManager$5
# 599        1100  L11061                             BlockingQueueManager$6
#
# ...

# %%
data.to_csv('fulldata.csv')

# %%
data =data.drop_duplicates()

# %%
data
# Out:
#      Unnamed: 0      ID                                               Name  \
# 0             0    L200                  AsyncClientCall<V extends Object>
# 1             1    L290                            AtomicNumberClientProxy
# 2             2    L381                            AuthenticationException
# 3             3    L214                                               Call
# 4             4    L467  ClientMapEntry<K extends Object, V extends Obj...
# ..          ...     ...                                                ...
# 595        1096  L11021                             BlockingQueueManager$2
# 596        1097  L11031                             BlockingQueueManager$3
# 597        1098  L11041                             BlockingQueueManager$4
# 598        1099  L11051                             BlockingQueueManager$5
# 599        1100  L11061                             BlockingQueueManager$6
#
# ...

# %%
data=data.drop('Unnamed: 0',axis=1)

# %%
data
# Out:
#          ID                                               Name  \
# 0      L200                  AsyncClientCall<V extends Object>
# 1      L290                            AtomicNumberClientProxy
# 2      L381                            AuthenticationException
# 3      L214                                               Call
# 4      L467  ClientMapEntry<K extends Object, V extends Obj...
# ..      ...                                                ...
# 595  L11021                             BlockingQueueManager$2
# 596  L11031                             BlockingQueueManager$3
# 597  L11041                             BlockingQueueManager$4
# 598  L11051                             BlockingQueueManager$5
# 599  L11061                             BlockingQueueManager$6
#
#                                          LongName  Parent Component  \
# 0            com.hazelcast.client.AsyncClientCall    L106      L103
# 1    com.hazelcast.client.AtomicNumberClientProxy    L106      L103
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import LabelEncoder
Lname = LabelEncoder()
LLongeName = LabelEncoder()
Lparents = LabelEncoder()
Lcomponent = LabelEncoder()
Lpath = LabelEncoder()

# %%
data['Name'] = Lname.fit_transform(data['Name'])
data['LongName'] = LLongeName.fit_transform(data['LongName'])
data['Parent'] = Lparents.fit_transform(data['Parent'])
data['Path'] = Lpath.fit_transform(data['Path'])
data['Component'] = Lcomponent.fit_transform(data['Component'])

# %%
data
# Out:
#          ID  Name  LongName  Parent  Component  Path  Line  Column  EndLine  \
# 0      L200    40         9       4          0     0    25       1      102
# 1      L290    41        10       4          0     1    26       1       96
# 2      L381    46        11       4          0     2    20       1       30
# 3      L214    99        12       4          0     3    26       1      115
# 4      L467   114        16       4          0     4    23       1       98
# ..      ...   ...       ...     ...        ...   ...   ...     ...      ...
# 595  L11021    70       410       7          0   270    51     127       55
# 596  L11031    71       411       7          0   270    56     139       60
# 597  L11041    72       412       7          0   270    61     139       65
# 598  L11051    73       413       7          0   270    66     131       70
# 599  L11061    74       414       7          0   270    71     138       75
#
#      EndColumn  ...  Naming Rules  Optimization Rules  \
# ...

# %%
plt.figure(figsize=[25,25])
data.boxplot()

# %%
data.corr()
# Out:
#                                        Name  LongName    Parent  Component  \
# Name                               1.000000  0.269206  0.175137        NaN
# LongName                           0.269206  1.000000  0.141088        NaN
# Parent                             0.175137  0.141088  1.000000        NaN
# Component                               NaN       NaN       NaN        NaN
# Path                               0.204193  0.710199  0.187250        NaN
# ...                                     ...       ...       ...        ...
# String and StringBuffer Rules      0.000594 -0.041904  0.060695        NaN
# Type Resolution Rules              0.027638  0.027684  0.106031        NaN
# Unnecessary and Unused Code Rules  0.006734  0.008274  0.094609        NaN
# Vulnerability Rules                     NaN       NaN       NaN        NaN
# Number of bugs                     0.016195  0.101410  0.108558        NaN
#
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'LongName', 'Parent', 'Component', 'Path', 'Line',
#        'Column', 'EndLine', 'EndColumn',
#        ...
#        'Naming Rules', 'Optimization Rules', 'Security Code Guideline Rules',
#        'Size Metric Rules', 'Strict Exception Rules',
#        'String and StringBuffer Rules', 'Type Resolution Rules',
#        'Unnecessary and Unused Code Rules', 'Vulnerability Rules',
#        'Number of bugs'],
#       dtype='object', length=113)

# %%
plt.figure(figsize=[25,25])
sns.heatmap(data.corr(),annot=True)

# %%
data.drop('Migration14 Rules',axis= True)
# Out:
#          ID  Name  LongName  Parent  Component  Path  Line  Column  EndLine  \
# 0      L200    40         9       4          0     0    25       1      102
# 1      L290    41        10       4          0     1    26       1       96
# 2      L381    46        11       4          0     2    20       1       30
# 3      L214    99        12       4          0     3    26       1      115
# 4      L467   114        16       4          0     4    23       1       98
# ..      ...   ...       ...     ...        ...   ...   ...     ...      ...
# 595  L11021    70       410       7          0   270    51     127       55
# 596  L11031    71       411       7          0   270    56     139       60
# 597  L11041    72       412       7          0   270    61     139       65
# 598  L11051    73       413       7          0   270    66     131       70
# 599  L11061    74       414       7          0   270    71     138       75
#
#      EndColumn  ...  Naming Rules  Optimization Rules  \
# ...
