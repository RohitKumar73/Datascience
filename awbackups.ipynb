# %%
import pymysql
import pandas as pd
import mysql.connector

db = mysql.connector.connect(
    host="localhost",
    user="root",
    passwd="",
    database ='adventureworks'
    )
print(db)

# %%
mycursor = db.cursor()

# %%
mycursor.execute("SHOW DATABASES")

# %%
for x in mycursor:
    print(x)
# Out:
# ('information_schema',)
# ('adventureworks',)
# ('mydatabase',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)
# ('vikedb',)

# %%
mycursor.execute('Select * from address')

# %%
for x in mycursor:
    print(x)
# Out:
# (1, '1970 Napa Ct.', 'Bothell', 79, '98011', bytearray(b'\r\xcb\xad\x9a\xcf6?H\x84\xd8X\\-N\xc6\xe9'), datetime.datetime(1998, 1, 4, 0, 0))
# (2, '9833 Mt. Dias Blv.', 'Bothell', 79, '98011', bytearray(b'\x9eK\xa524\xe0\xfbK\xb5s\xa7\x1c\xde`\xd8\xc0'), datetime.datetime(1999, 1, 1, 0, 0))
# (3, '7484 Roundtree Drive', 'Bothell', 79, '98011', bytearray(b'#iPL\x1bm,E\xa0|\xba\xa6\xf5\xb1B\xa4'), datetime.datetime(2003, 4, 8, 0, 0))
# (4, '9539 Glenside Dr', 'Bothell', 79, '98011', bytearray(b'xl\x94\xe5\xccK\x7fG\x9f\xa1\xcc\t\xde\x16\xa8\x80'), datetime.datetime(1999, 3, 7, 0, 0))
# (5, '1226 Shoe St.', 'Bothell', 79, '98011', bytearray(b'7\xf9\xaf\xfb\x97J\xf0J\x81\xfd\xb8I\x90\x0e\x9b\xb0'), datetime.datetime(1999, 1, 20, 0, 0))
# (6, '1399 Firestone Drive', 'Bothell', 79, '98011', bytearray(b'\x91\x81\xbf\xfe\x04\x98\xc8D\x87z3\xfd\xe9O\x00u'), datetime.datetime(1999, 3, 17, 0, 0))
# ...

# %%
mycursor.execute('Select count(*) from address')

# %%
for x in mycursor:
    print(x)
# Out:
# (19614,)

# %%
mycursor.execute('Select * from countryregion')

# %%
for x in mycursor:
    print(x)
# Out:
# ('AD', 'Andorra', datetime.datetime(1998, 6, 1, 0, 0))
# ('AE', 'United Arab Emirates', datetime.datetime(1998, 6, 1, 0, 0))
# ('AF', 'Afghanistan', datetime.datetime(1998, 6, 1, 0, 0))
# ('AG', 'Antigua and Barbuda', datetime.datetime(1998, 6, 1, 0, 0))
# ('AI', 'Anguilla', datetime.datetime(1998, 6, 1, 0, 0))
# ('AL', 'Albania', datetime.datetime(1998, 6, 1, 0, 0))
# ('AM', 'Armenia', datetime.datetime(1998, 6, 1, 0, 0))
# ('AN', 'Netherlands Antilles', datetime.datetime(1998, 6, 1, 0, 0))
# ('AO', 'Angola', datetime.datetime(1998, 6, 1, 0, 0))
# ('AQ', 'Antarctica', datetime.datetime(1998, 6, 1, 0, 0))
# ('AR', 'Argentina', datetime.datetime(1998, 6, 1, 0, 0))
# ('AS', 'American Samoa', datetime.datetime(1998, 6, 1, 0, 0))
# ('AT', 'Austria', datetime.datetime(1998, 6, 1, 0, 0))
# ('AU', 'Australia', datetime.datetime(1998, 6, 1, 0, 0))
# ('AW', 'Aruba', datetime.datetime(1998, 6, 1, 0, 0))
# ('AZ', 'Azerbaijan', datetime.datetime(1998, 6, 1, 0, 0))
# ...

# %%
mycursor.execute('Select count(*),city from address group by city ')

# %%
for x in mycursor:
    print(x)
# Out:
# (1, 'Abingdon')
# (4, 'Albany')
# (2, 'Alexandria')
# (1, 'Alhambra')
# (1, 'Alpine')
# (2, 'Altadena')
# (1, 'Altamonte Springs')
# (3, 'Anacortes')
# (1, 'Arlington')
# (1, 'Ascheim')
# (2, 'Atlanta')
# (1, 'Auburn')
# (2, 'Augsburg')
# (1, 'Augusta')
# (1, 'Aujan Mournede')
# (1, 'Aurora')
# (1, 'Austell')
# (2, 'Austin')
# (1, 'Bad Soden')
# (1, 'Baldwin Park')
# (69, 'Ballard')
# (1, 'Baltimore')
# (1, 'Barrie')
# (2, 'Barstow')
# (3, 'Basingstoke Hants')
# (2, 'Baytown')
# (213, 'Beaverton')
# (2, 'Bell Gardens')
# (41, 'Bellevue')
# (194, 'Bellflower')
# (213, 'Bellingham')
# (104, 'Bendigo')
# (202, 'Berkeley')
# (32, 'Berks')
# (32, 'Berkshire')
# (193, 'Berlin')
# (188, 'Beverly Hills')
# (56, 'Billericay')
# (2, 'Billings')
# (2, 'Biloxi')
# (34, 'Birmingham')
# (2, 'Bluffton')
# (58, 'Bobigny')
# (1, 'Boise')
# (64, 'Bonn')
# (1, 'Bordeaux')
# (1, 'Boston')
# (26, 'Bothell')
# (57, 'Bottrop')
# (15, 'Boulogne-Billancourt')
# (17, 'Boulogne-sur-Mer')
# (2, 'Bountiful')
# ...

# %%
mycursor.execute("select Count(*),City from address where ModifiedDate is not null group by City order by count(*) asc;")

# %%
for x in mycursor:
    print(x)
# Out:
# (1, 'Madison Heights')
# (1, 'Federal Way')
# (1, 'Somerset')
# (1, 'Upland')
# (1, 'Van Nuys')
# (1, 'Humble')
# (1, 'West Kingston')
# (1, 'La Vergne')
# (1, 'Newport')
# (1, 'Newark')
# (1, 'Brampton')
# (1, 'Joliet')
# (1, 'New Castle')
# (1, 'Wenatchee')
# (1, 'Suwanee')
# (1, 'Gulfport')
# (1, 'Stockton')
# (1, 'Tooele')
# (1, 'Nepean')
# (1, 'Denby')
# (1, 'Stamford')
# (1, 'Saugus')
# (1, 'Shelton')
# (1, 'Winston-Salem')
# (1, 'Hollywood')
# (1, 'North Sioux City')
# (1, 'Mentor')
# (1, 'Redford')
# (1, 'Altamonte Springs')
# (1, 'Austell')
# (1, 'Las Cruces')
# (1, 'Baldwin Park')
# (1, 'Markham')
# (1, 'Waterbury')
# (1, 'Tilton')
# (1, 'Kennewick')
# (1, 'Hixson')
# (1, 'San Ramon')
# (1, 'Escondido')
# (1, 'Parker')
# (1, 'Euclid')
# (1, 'Port Huron')
# (1, 'Rock Springs')
# (1, 'Gaffney')
# (1, 'Hayward')
# (1, 'Park City')
# (1, 'North Las Vegas')
# (1, 'Peoria')
# (1, 'Newport News')
# (1, 'Southgate')
# (1, 'New Haven')
# (1, 'Tampa')
# (1, 'Pleasanton')
# ...
